# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [1,4,9,16]
#plt.plot(x,y,'ro')
#plt.plot(x,y,'b+')
#plt.plot(x,y,'y*')
#plt.plot(x,y,'y')
plt.plot(x,y,'ys')
plt.show()

# %%
import pandas as pd
import numpy as np

Titanic = pd.read_csv("titanic-passengers.csv",sep=";")
Titanic.Age.isnull().sum()
# Out:
# 177

# %%
Titanic.Age.fillna(Titanic.Age.mean(),inplace =True)

# %%
Titanic.Age.isnull().sum()
# Out:
# 0

# %%
Titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
import matplotlib.pyplot as plt
Titanic.Age.plot.hist()
plt.xlabel("Age")
plt.ylabel("Number of Person")
plt.title("Histogram of Ages")
# Out:
# Text(0.5, 1.0, 'Histogram of Ages')

# %%
import seaborn as sns
sns.distplot(Titanic.Age,bins = 10,hist = True, kde = True, color = "Red" )
# Out:
# C:\Users\Abderrahmen Mansour\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
import seaborn as sns
sns.displot(Titanic.Age,bins = 10, kde = True, color = "Red" )

# %%
import seaborn as sns
sns.histplot(Titanic.Age,bins = 10, kde = True, color = "Red" )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.displot(Titanic,x ="Age",bins = 20,kde = 20, color ="Green")

# %%
sns.histplot(Titanic,x ="Age",bins = 20,kde = 20, color ="Green")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Titanic.Survived.value_counts()
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
plt.xlabel("Survived")
plt.xlabel("Survived Value Counts")
plt.title("Bar plot of Survived")
vs = Titanic.Survived.value_counts()
print(vs,type(vs))
vs.plot.bar(rot = 10)
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64 <class 'pandas.core.series.Series'>
# <AxesSubplot:title={'center':'Bar plot of Survived'}, xlabel='Survived Value Counts'>

# %%
sns.countplot(x = "Survived", data= Titanic)
plt.xticks(rotation =  10)
# Out:
# (array([0, 1]), [Text(0, 0, 'No'), Text(1, 0, 'Yes')])

# %%
Titanic.Age.plot.box()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(Titanic.Age, width = 0.5)
# Out:
# C:\Users\Abderrahmen Mansour\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x = Titanic.Age, width = 0.5)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
New_data = Titanic.drop(["Survived", "Pclass","Name", "Sex","SibSp","Parch","Ticket","Cabin","Embarked"], axis =1)
New_data
# Out:
#      PassengerId        Age     Fare
# 0            343  28.000000  13.0000
# 1             76  25.000000   7.6500
# 2            641  20.000000   7.8542
# 3            568  29.000000  21.0750
# 4            672  31.000000  52.0000
# ..           ...        ...      ...
# 886           10  14.000000  30.0708
# 887           61  22.000000   7.2292
# 888          535  30.000000   8.6625
# 889          102  29.699118   7.8958
# 890          428  19.000000  26.0000
#
# [891 rows x 3 columns]

# %%
sns.boxplot(data = New_data)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
New_data.PassengerId = scaler.fit_transform(New_data.PassengerId.values)

New_data.Age = scaler.fit_transform(New_data.Age.values)
New_data.Fare = scaler.fit_transform(New_data.Fare.values)
sns.boxplot(data = New_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ABDERR~1\AppData\Local\Temp/ipykernel_11792/963179246.py in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler =StandardScaler()
# ----> 3 New_data.PassengerId = scaler.fit_transform(New_data.PassengerId.values)
#       4
#       5 New_data.Age = scaler.fit_transform(New_data.Age.values)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
# ...

# %%
a =New_data.PassengerId.values
a.reshape(891,1)
# Out:
# array([[-0.40045195],
#        [-1.43851673],
#        [ 0.75813719],
#        [ 0.47432173],
#        [ 0.87866157],
#        [-1.32576812],
#        [ 0.5054248 ],
#        [-0.24882452],
#        [-0.8475585 ],
#        [-0.05054248],
#        [-1.20913163],
#        [-0.59095822],
#        [ 1.20135586],
#        [ 0.57929457],
#        [-1.24023469],
#        [-0.0466546 ],
#        [-0.26437605],
#        [ 0.33824583],
#        [ 0.85533427],
#        [-0.85922215],
#        [-1.41130155],
#        [-1.22857104],
#        [ 0.38101254],
#        [ 1.43462885],
#        [-0.67260377],
#        [ 0.06998189],
#        [ 0.55207939],
#        [ 0.83589486],
#        [-1.38408637],
#        [-1.28688929],
#        [-0.28381546],
#        [ 1.1002709 ],
#        [ 0.31880641],
#        [ 0.35379736],
#        [ 1.09249514],
#        [-1.61347147],
#        [ 0.12052437],
#        [-0.05831825],
#        [ 0.8475585 ],
#        [-1.56292899],
#        [-0.38490042],
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
New_data.PassengerId = scaler.fit_transform(New_data.PassengerId.values.reshape(891,1))

New_data.Age = scaler.fit_transform(New_data.Age.values.reshape(891,1))
New_data.Fare = scaler.fit_transform(New_data.Fare.values.reshape(891,1))
sns.boxplot(data = New_data)
# Out:
# <AxesSubplot:>

# %%
a = New_data.PassengerId.values.reshape(891,1)
print(a)
a.shape
# Out:
# [[-4.00451954e-01]
#  [-1.43851673e+00]
#  [ 7.58137195e-01]
#  [ 4.74321732e-01]
#  [ 8.78661569e-01]
#  [-1.32576812e+00]
#  [ 5.05424796e-01]
#  [-2.48824515e-01]
#  [-8.47558505e-01]
#  [-5.05424796e-02]
#  [-1.20913163e+00]
#  [-5.90958223e-01]
#  [ 1.20135586e+00]
#  [ 5.79294574e-01]
#  [-1.24023469e+00]
#  [-4.66545966e-02]
#  [-2.64376047e-01]
#  [ 3.38245825e-01]
#  [ 8.55334271e-01]
#  [-8.59222154e-01]
#  [-1.41130155e+00]
#  [-1.22857104e+00]
#  [ 3.81012539e-01]
#  [ 1.43462885e+00]
#  [-6.72603768e-01]
#  [ 6.99818949e-02]
#  [ 5.52079393e-01]
#  [ 8.35894856e-01]
#  [-1.38408637e+00]
#  [-1.28688929e+00]
#  [-2.83815463e-01]
#  [ 1.10027090e+00]
#  [ 3.18806410e-01]
#  [ 3.53797357e-01]
#  [ 1.09249514e+00]
#  [-1.61347147e+00]
#  [ 1.20524375e-01]
#  [-5.83182457e-02]
#  [ 8.47558505e-01]
#  [-1.56292899e+00]
#  [-3.84900422e-01]
#  [ 1.73010796e+00]
#  [-1.34520754e+00]
#  [-1.45406826e+00]
#  [-9.64194996e-01]
#  [-5.40415744e-01]
#  [ 1.00307383e+00]
# ...

# %%
b = New_data.PassengerId.values
print(b)
print(b.shape)
c = New_data.PassengerId.values.transpose().transpose()
print(c)
c.shape
# Out:
# [-4.00451954e-01 -1.43851673e+00  7.58137195e-01  4.74321732e-01
#   8.78661569e-01 -1.32576812e+00  5.05424796e-01 -2.48824515e-01
#  -8.47558505e-01 -5.05424796e-02 -1.20913163e+00 -5.90958223e-01
#   1.20135586e+00  5.79294574e-01 -1.24023469e+00 -4.66545966e-02
#  -2.64376047e-01  3.38245825e-01  8.55334271e-01 -8.59222154e-01
#  -1.41130155e+00 -1.22857104e+00  3.81012539e-01  1.43462885e+00
#  -6.72603768e-01  6.99818949e-02  5.52079393e-01  8.35894856e-01
#  -1.38408637e+00 -1.28688929e+00 -2.83815463e-01  1.10027090e+00
#   3.18806410e-01  3.53797357e-01  1.09249514e+00 -1.61347147e+00
#   1.20524375e-01 -5.83182457e-02  8.47558505e-01 -1.56292899e+00
#  -3.84900422e-01  1.73010796e+00 -1.34520754e+00 -1.45406826e+00
#  -9.64194996e-01 -5.40415744e-01  1.00307383e+00 -1.53571380e+00
#  -1.82730503e-01  4.54882317e-01 -1.01084959e+00  1.43851673e-01
#  -3.88788305e-03  1.52793804e+00 -1.44240461e+00  9.75858645e-01
# ...

# %%
import numpy as np
import pandas as pd
#New_data.PassengerId.values.to_frame().reset_index()
type(New_data.PassengerId.values)

a = pd.DataFrame(New_data.PassengerId.values)
a
# Out:
#             0
# 0   -0.400452
# 1   -1.438517
# 2    0.758137
# 3    0.474322
# 4    0.878662
# ..        ...
# 886 -1.695117
# 887 -1.496835
# 888  0.346022
# 889 -1.337432
# 890 -0.069982
#
# [891 rows x 1 columns]

# %%
scaler.fit_transform( pd.DataFrame(New_data.PassengerId.values))
# Out:
# array([[-4.00451954e-01],
#        [-1.43851673e+00],
#        [ 7.58137195e-01],
#        [ 4.74321732e-01],
#        [ 8.78661569e-01],
#        [-1.32576812e+00],
#        [ 5.05424796e-01],
#        [-2.48824515e-01],
#        [-8.47558505e-01],
#        [-5.05424796e-02],
#        [-1.20913163e+00],
#        [-5.90958223e-01],
#        [ 1.20135586e+00],
#        [ 5.79294574e-01],
#        [-1.24023469e+00],
#        [-4.66545966e-02],
#        [-2.64376047e-01],
#        [ 3.38245825e-01],
#        [ 8.55334271e-01],
#        [-8.59222154e-01],
#        [-1.41130155e+00],
#        [-1.22857104e+00],
#        [ 3.81012539e-01],
#        [ 1.43462885e+00],
#        [-6.72603768e-01],
#        [ 6.99818949e-02],
#        [ 5.52079393e-01],
#        [ 8.35894856e-01],
#        [-1.38408637e+00],
#        [-1.28688929e+00],
#        [-2.83815463e-01],
#        [ 1.10027090e+00],
#        [ 3.18806410e-01],
#        [ 3.53797357e-01],
#        [ 1.09249514e+00],
# ...

# %%
### Switch to Dataframe

from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
New_data.PassengerId = scaler.fit_transform(pd.DataFrame(New_data.PassengerId.values))

New_data.Age = scaler.fit_transform(pd.DataFrame(New_data.Age.values))
New_data.Fare = scaler.fit_transform(pd.DataFrame(New_data.Fare.values))
sns.boxplot(data = New_data)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
New_data.PassengerId = scaler.fit_transform(New_data.PassengerId.values.reshape(891,1))

New_data.Age = scaler.fit_transform(New_data.Age.values.reshape(891,1))
New_data.Fare = scaler.fit_transform(New_data.Fare.values.reshape(891,1))
sns.boxplot(data = New_data)
# Out:
# <AxesSubplot:>

# %%
New_data
# Out:
#      PassengerId           Age      Fare
# 0      -0.400452 -1.307545e-01 -0.386671
# 1      -1.438517 -3.616175e-01 -0.494391
# 2       0.758137 -7.463893e-01 -0.490280
# 3       0.474322 -5.380014e-02 -0.224083
# 4       0.878662  1.001086e-01  0.398582
# ..           ...           ...       ...
# 886    -1.695117 -1.208115e+00 -0.042956
# 887    -1.496835 -5.924806e-01 -0.502864
# 888     0.346022  2.315421e-02 -0.474005
# 889    -1.337432 -2.352526e-16 -0.489442
# 890    -0.069982 -8.233437e-01 -0.124920
#
# [891 rows x 3 columns]

# %%
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Titanic
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
# Age Vs Survived 
g = sns.FacetGrid(Titanic, col='Survived')
g.map(plt.hist,"Age",bins=5)

# %%
# Sex Vs Survived 
g1 = sns.FacetGrid(Titanic, col='Survived')
g1.map(plt.hist,"Sex",bins=10)

# %%
Titanic.Embarked.value_counts()
Titanic.Embarked.fillna("S",inplace = True)

# %%
Titanic.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
# Age/Fare Survived/sex
grid = sns.FacetGrid(Titanic, row = "Sex", col = "Survived", height = 3.2, aspect =1.6)
grid.map(sns.barplot,"Age","Fare", alpha =.5,ci = None)
#,order = ["Age","Fare"]
grid.add_legend()
# Out:
# C:\Users\Abderrahmen Mansour\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
Titanic.Survived.value_counts()
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
cleanup ={"Survived":{"Yes":1,"No":0}}
Titanic.replace(cleanup,inplace =True)
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
Titanic.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
Titanic[["Sex","Survived"]].groupby(["Survived"],as_index = True).mean()
# Out:
# C:\Users\Abderrahmen Mansour\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
Titanic[[ "Sex", "Survived" ]].groupby( [ "Survived" ], as_index = True ).mean()
# Out:
# C:\Users\Abderrahmen Mansour\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
Titanic[[ "Sex", "Survived" ]].groupby( by = [ "Survived" ] , axis=0, level=None, as_index=True, sort=True, group_keys=True,  observed=True, dropna=True).mean()
#Titanic[[ "Sex", "Survived" ]].groupby( [ "Survived" ], as_index = True ).mean()
# Out:
# C:\Users\Abderrahmen Mansour\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
Titanic[[ "Sex", "Survived" ]].groupby( by = [ "Survived" ] , axis=0, level=None, as_index=True).mean()
# Out:
# C:\Users\Abderrahmen Mansour\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
Titanic[[ "Sex", "Survived" ]].groupby( by = [ "Sex" ] , axis=0, level=None, as_index=True).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
Titanic[[ "Embarked" , "Survived" ]].groupby( by = [ "Embarked" ] , axis=0, level=None, as_index=True).mean()
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.339009

# %%
Titanic[[  "Survived" ,"Embarked"]].groupby( by = [ "Embarked" ] , axis=0, level=None, as_index=True).mean()
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.339009

# %%
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
corrMatrix = Titanic.corr()
fig, ax = plt.subplots(figsize=(18,9))
sns.heatmap(corrMatrix, annot=True, linewidths=.5, ax=ax)

plt.show()

# %% [markdown]
# df = pd.DataFrame({'fert_Rate': [1,3,4,5,6,6,6,]})
# df.assign(fertility=pd.cut(df['fert_Rate'],
#                                bins=[0, 2, 3.5, 999],
#                                labels=['Low', 'Medium', 'High']))

# %%
import pandas as pd
df = pd.DataFrame({'fert_Rate': [1,3,4,5,6,6,6,]})
df
# Out:
#    fert_Rate
# 0          1
# 1          3
# 2          4
# 3          5
# 4          6
# 5          6
# 6          6

# %%
df.assign(fertility=pd.cut(df['fert_Rate'], bins=[0, 2, 3.5, 999], labels=['Low', 'Medium', 'High']))
# Out:
#    fert_Rate fertility
# 0          1       Low
# 1          3    Medium
# 2          4      High
# 3          5      High
# 4          6      High
# 5          6      High
# 6          6      High

# %%
df.fert_Rate
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    6
# 6    6
# Name: fert_Rate, dtype: int64
